# %%
import sqlite3
import sqlite_vss
conn = sqlite3.connect("test.db")
conn.enable_load_extension(True)
sqlite_vss.load(conn)
conn.enable_load_extension(False)
version, = conn.execute('select vss_version()').fetchone()
print(version)
# Out:
# v0.1.2

# %%
cursor = conn.cursor()
sql_virtual_table = """
    create virtual table vss_wiki using vss0(
        passage_embedding(384)
    );
"""
sql_insert_table = """
        insert into vss_wiki(rowid, passage_embedding) select rowid, embedding from wiki_embedding;
"""
#cursor.execute(sql_virtual_table)
cursor.execute(sql_insert_table)
cursor.close()
    #cursor.execute("CREATE TABLE wiki_embedding (ind INTEGER, title TEXT, embedding blob)")

# %%
cursor = conn.cursor()
res = cursor.execute(" select * from wiki_embedding limit 10")
res = res.fetchall()
print(res[0])
print(res[6])
cursor.close()
# Out:
# (10, 'AccessibleComputing', b'\xd1\xc5\xd2<N)\x7f<\xac\x94\x87\xbcM\xcc\xb8\xbc\xa5\xe8@=H\xd4M=\xec\x17\x01=\x95\'\x8a=\x9cj\x16\xbd\x95\xe6\x80\xbc}yY<9}\x1a=\x11\x8c\x1b\xba\xa4c\xd9<^>\x04\xbb6\xd7\x8f\xbdq\xc6\x1c\xbdF\x02\xa2<k\x1f\x1b=\x7f\xe98\xbd$\xbf\x10=\xcaRC=\xb1J\xf2\xbb\xa4\r\xbf\xbd6S\xeb\xbc\xe66\xe7<\xb4\xcfh=x\xc6\xd4\xbdw\xb2\xf3\xbcg\xa2\xa8\xbdS\xb0\xbc\xbd\xbb(\x82\xbaD\xe1!\xbd\x1d<\xd4\xbc\xd7\x1ff;\x97\xd7R=\xb9!\x0f=m\x8af\xbc\x89N\x95=\xf8\xcb_\xbd\xd2s\xbf<\xf9\xe8\x97;*\x06f=\x8e\x0f\'\xbd=)|\xbd\x04\xb0\xbd\xbcE\x16\xd3\xbd\xb6\xc2\x82;\xc5,\x8a<\xb6\xc1\xef<w\xe1\xea\xbc`B\xd7\xbc\xf8\xa1\x9e<\x1d\xc9\x03=\\V\x8d\xbd\x08\xa2`<\xd8)\'<\x0b\x8aB=>\x94/=ym\xd7\xbd|\x8a!\xbb\xf4\xaa\x87\xbd\x12 R\xbc\xe3\xbbt\xbc\x1d5\xfb\xbc\xa1\x1b\xbc\xbb\xfes\xa4\xbah\xf6H=:\x0b\x05\xbdSk\xeb=A)\xc9\xbc\xcaqJ;\xec\x96\x9e\xbd\x9dqa\xbd\xf4\x97M=\x1e\x0b\x94\xbd\xdc:\x89\xbb\x9b\xe5\xac=1\x08\x0f=\xd3\x9c\xff;\x1d\xb4S=\x07\xfd\x12=\xa6\xbdz\xbd [+=3\x87e<\xb3\x9f\'>\xc
# ...

# %%
conn.close()
